# %%
from __future__ import print_function
import numpy as np
np.random.seed(1337)  # for reproducibility
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Lambda
from keras.layers import Embedding
from keras.layers import Convolution1D,MaxPooling1D, Flatten
from keras.datasets import imdb
from keras import backend as K
from sklearn.model_selection import train_test_split
import pandas as pd
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import Normalizer
from keras.models import Sequential
from keras.layers import Convolution1D, Dense, Dropout, Flatten, MaxPooling1D
from keras.utils import np_utils
import numpy as np
import h5py
from keras import callbacks
from keras.layers import LSTM, GRU, SimpleRNN
from keras.callbacks import CSVLogger
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# %%
from google.colab import files
files.upload()

# !pip install -q kaggle

# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# This permissions change avoids a warning on Kaggle tool startup.
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-4980d655-c960-4dd4-8ffc-ff9856bed324" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4980d655-c960-4dd4-8ffc-ff9856bed324">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %%
# !kaggle datasets download -d kiranmahesh/nslkdd
# Out:
# Downloading nslkdd.zip to /content
#   0% 0.00/2.56M [00:00<?, ?B/s]
# 100% 2.56M/2.56M [00:00<00:00, 85.9MB/s]

# %%
from zipfile import ZipFile
file_name='/content/nslkdd.zip'
with ZipFile(file_name,'r') as zip:
  zip.extractall()

# %%
traindata = pd.read_csv('/content/kdd_train.csv')
testdata = pd.read_csv('/content/kdd_test.csv')

# %%
data = pd.concat([traindata,testdata])
data.head()
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  25
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  26
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# 2                    0.10                    0.05
# 3                    1.00                    0.00
# 4                    1.00                    0.00
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                         0.17                         0.00
# 1                         0.88                         0.00
# 2                         0.00                         0.00
# 3                         0.03                         0.04
# 4                         0.00                         0.00
#
#    dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                  0.00                      0.00                  0.05
# 1                  0.00                      0.00                  0.00
# 2                  1.00                      1.00                  0.00
# 3                  0.03                      0.01                  0.00
# 4                  0.00                      0.00                  0.00
#
#    dst_host_srv_rerror_rate   labels
# 0                      0.00   normal
# 1                      0.00   normal
# 2                      0.00  neptune
# 3                      0.01   normal
# 4                      0.00   normal
#
# [5 rows x 42 columns]

# %%
categ = ['protocol_type','service','flag','labels']
# Encode Categorical Columns
le = LabelEncoder()
data[categ] = data[categ].apply(le.fit_transform)
#data[categ] = testdata[categ].apply(le.fit_transform)

# %%
X = data.iloc[:,1:41]
Y = data['labels']

# %%
scaler = Normalizer().fit(X)
X = scaler.transform(X)

# %%
X_train, X_test,Y_train,Y_test = train_test_split(X,Y, test_size=0.2)

# %%
# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0],X_train.shape[1],1))
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))

# %%
model = Sequential()
model.add(Dense(128,input_shape=(40, 1),activation='relu'))  
model.add(Dropout(0.01))
model.add(Flatten())
model.add(Dense(40))
model.add(Activation('softmax'))

# %%
model.compile(loss="sparse_categorical_crossentropy", optimizer="adam",metrics=['accuracy'])

# %%
checkpointer = callbacks.ModelCheckpoint(filepath="results/cnn1results/checkpoint-{epoch:02d}.hdf5", verbose=1, save_best_only=True, monitor='val_acc',mode='max')

# %%
history=model.fit(X_train, Y_train, epochs=75,verbose=1,batch_size=500,validation_data=(X_test, Y_test),callbacks=[checkpointer])
# Out:
# Epoch 1/75
# 237/238 [============================>.] - ETA: 0s - loss: 1.0231 - accuracy: 0.7773WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 10ms/step - loss: 1.0220 - accuracy: 0.7774 - val_loss: 0.5176 - val_accuracy: 0.8630
# Epoch 2/75
# 234/238 [============================>.] - ETA: 0s - loss: 0.4828 - accuracy: 0.8659WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 3s 11ms/step - loss: 0.4822 - accuracy: 0.8663 - val_loss: 0.4478 - val_accuracy: 0.8860
# Epoch 3/75
# 237/238 [============================>.] - ETA: 0s - loss: 0.4393 - accuracy: 0.8837WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 3s 13ms/step - loss: 0.4391 - accuracy: 0.8838 - val_loss: 0.4170 - val_accuracy: 0.8904
# Epoch 4/75
# 236/238 [============================>.] - ETA: 0s - loss: 0.4126 - accuracy: 0.8903WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 3s 13ms/step - loss: 0.4123 - accuracy: 0.8905 - val_loss: 0.3931 - val_accuracy: 0.8922
# Epoch 5/75
# 234/238 [============================>.] - ETA: 0s - loss: 0.3902 - accuracy: 0.8942WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 3s 12ms/step - loss: 0.3899 - accuracy: 0.8942 - val_loss: 0.3773 - val_accuracy: 0.8954
# Epoch 6/75
# 236/238 [============================>.] - ETA: 0s - loss: 0.3718 - accuracy: 0.8972WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 3s 13ms/step - loss: 0.3716 - accuracy: 0.8973 - val_loss: 0.3592 - val_accuracy: 0.9020
# Epoch 7/75
# 234/238 [============================>.] - ETA: 0s - loss: 0.3562 - accuracy: 0.8995WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 3s 13ms/step - loss: 0.3558 - accuracy: 0.8995 - val_loss: 0.3460 - val_accuracy: 0.9026
# Epoch 8/75
# 237/238 [============================>.] - ETA: 0s - loss: 0.3434 - accuracy: 0.9013WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 4s 15ms/step - loss: 0.3432 - accuracy: 0.9013 - val_loss: 0.3318 - val_accuracy: 0.9032
# Epoch 9/75
# 235/238 [============================>.] - ETA: 0s - loss: 0.3333 - accuracy: 0.9030WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 3s 13ms/step - loss: 0.3332 - accuracy: 0.9031 - val_loss: 0.3256 - val_accuracy: 0.9018
# Epoch 10/75
# 235/238 [============================>.] - ETA: 0s - loss: 0.3244 - accuracy: 0.9058WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 3s 13ms/step - loss: 0.3245 - accuracy: 0.9057 - val_loss: 0.3147 - val_accuracy: 0.9041
# Epoch 11/75
# 235/238 [============================>.] - ETA: 0s - loss: 0.3176 - accuracy: 0.9088WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 3s 12ms/step - loss: 0.3176 - accuracy: 0.9088 - val_loss: 0.3087 - val_accuracy: 0.9089
# Epoch 12/75
# 237/238 [============================>.] - ETA: 0s - loss: 0.3112 - accuracy: 0.9111WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 3s 13ms/step - loss: 0.3112 - accuracy: 0.9111 - val_loss: 0.3039 - val_accuracy: 0.9144
# Epoch 13/75
# 238/238 [==============================] - ETA: 0s - loss: 0.3053 - accuracy: 0.9140WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 3s 11ms/step - loss: 0.3053 - accuracy: 0.9140 - val_loss: 0.2998 - val_accuracy: 0.9180
# Epoch 14/75
# 236/238 [============================>.] - ETA: 0s - loss: 0.3005 - accuracy: 0.9161WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 2s
ARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 2s 9ms/step - loss: 0.1795 - accuracy: 0.9525 - val_loss: 0.1859 - val_accuracy: 0.9521
# Epoch 62/75
# 234/238 [============================>.] - ETA: 0s - loss: 0.1786 - accuracy: 0.9529WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 2s 9ms/step - loss: 0.1786 - accuracy: 0.9529 - val_loss: 0.1874 - val_accuracy: 0.9576
# Epoch 63/75
# 237/238 [============================>.] - ETA: 0s - loss: 0.1758 - accuracy: 0.9536WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 2s 9ms/step - loss: 0.1759 - accuracy: 0.9536 - val_loss: 0.1815 - val_accuracy: 0.9537
# Epoch 64/75
# 233/238 [============================>.] - ETA: 0s - loss: 0.1753 - accuracy: 0.9536WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 2s 9ms/step - loss: 0.1750 - accuracy: 0.9536 - val_loss: 0.1795 - val_accuracy: 0.9598
# Epoch 65/75
# 234/238 [============================>.] - ETA: 0s - loss: 0.1741 - accuracy: 0.9546WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 2s 9ms/step - loss: 0.1740 - accuracy: 0.9546 - val_loss: 0.1792 - val_accuracy: 0.9553
# Epoch 66/75
# 234/238 [============================>.] - ETA: 0s - loss: 0.1719 - accuracy: 0.9545WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 2s 9ms/step - loss: 0.1716 - accuracy: 0.9545 - val_loss: 0.1756 - val_accuracy: 0.9544
# Epoch 67/75
# 234/238 [============================>.] - ETA: 0s - loss: 0.1701 - accuracy: 0.9553WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 2s 9ms/step - loss: 0.1698 - accuracy: 0.9552 - val_loss: 0.1750 - val_accuracy: 0.9568
# Epoch 68/75
# 234/238 [============================>.] - ETA: 0s - loss: 0.1681 - accuracy: 0.9555WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 2s 9ms/step - loss: 0.1683 - accuracy: 0.9555 - val_loss: 0.1767 - val_accuracy: 0.9574
# Epoch 69/75
# 237/238 [============================>.] - ETA: 0s - loss: 0.1674 - accuracy: 0.9561WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 2s 9ms/step - loss: 0.1676 - accuracy: 0.9560 - val_loss: 0.1743 - val_accuracy: 0.9558
# Epoch 70/75
# 233/238 [============================>.] - ETA: 0s - loss: 0.1657 - accuracy: 0.9567WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 2s 9ms/step - loss: 0.1657 - accuracy: 0.9568 - val_loss: 0.1716 - val_accuracy: 0.9549
# Epoch 71/75
# 233/238 [============================>.] - ETA: 0s - loss: 0.1635 - accuracy: 0.9572WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 2s 9ms/step - loss: 0.1638 - accuracy: 0.9573 - val_loss: 0.1761 - val_accuracy: 0.9565
# Epoch 72/75
# 235/238 [============================>.] - ETA: 0s - loss: 0.1628 - accuracy: 0.9578WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 2s 9ms/step - loss: 0.1628 - accuracy: 0.9578 - val_loss: 0.1693 - val_accuracy: 0.9601
# Epoch 73/75
# 234/238 [============================>.] - ETA: 0s - loss: 0.1614 - accuracy: 0.9583WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 2s 9ms/step - loss: 0.1612 - accuracy: 0.9583 - val_loss: 0.1703 - val_accuracy: 0.9577
# Epoch 74/75
# 233/238 [============================>.] - ETA: 0s - loss: 0.1586 - accuracy: 0.9591WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 2s 9ms/step - loss: 0.1598 - accuracy: 0.9590 - val_loss: 0.1698 - val_accuracy: 0.9570
# Epoch 75/75
# 233/238 [============================>.] - ETA: 0s - loss: 0.1580 - accuracy: 0.9598WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 2s 9ms/step - loss: 0.1580 - accuracy: 0.9598 - val_loss: 0.1667 - val_accuracy: 0.9628

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
model.save("results/cnn1results/cnn_model.hdf5")
