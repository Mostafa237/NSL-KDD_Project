# %%
from google.colab import files
files.upload()

# !pip install -q kaggle

# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# This permissions change avoids a warning on Kaggle tool startup.
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-3416f44c-e38b-4cbb-b304-3787b543dd56" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3416f44c-e38b-4cbb-b304-3787b543dd56">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle (2).json

# %%
# !kaggle datasets download -d kiranmahesh/nslkdd
# Out:
# nslkdd.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
from zipfile import ZipFile
file_name='/content/nslkdd.zip'
with ZipFile(file_name,'r') as zip:
  zip.extractall()

# %%
from __future__ import print_function
import numpy as np
np.random.seed(1337)  # for reproducibility
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Lambda
from keras.layers import Embedding
from keras.layers import Convolution1D,MaxPooling1D, Flatten
from keras.datasets import imdb
from keras import backend as K
from sklearn.model_selection import train_test_split
import pandas as pd
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import Normalizer
from keras.models import Sequential
from keras.layers import Convolution1D, Dense, Dropout, Flatten, MaxPooling1D
from keras.utils import np_utils
import numpy as np
import h5py
from keras import callbacks
from keras.layers import LSTM, GRU, SimpleRNN
from keras.callbacks import CSVLogger
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
from imblearn.over_sampling import ADASYN
from imblearn.over_sampling import SMOTE

# %%
traindata = pd.read_csv('/content/kdd_train.csv')
testdata = pd.read_csv('/content/kdd_test.csv')

# %%
data= pd.concat([traindata,testdata])
data.head()
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  25
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  26
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# 2                    0.10                    0.05
# 3                    1.00                    0.00
# 4                    1.00                    0.00
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                         0.17                         0.00
# 1                         0.88                         0.00
# 2                         0.00                         0.00
# 3                         0.03                         0.04
# 4                         0.00                         0.00
#
#    dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                  0.00                      0.00                  0.05
# 1                  0.00                      0.00                  0.00
# 2                  1.00                      1.00                  0.00
# 3                  0.03                      0.01                  0.00
# 4                  0.00                      0.00                  0.00
#
#    dst_host_srv_rerror_rate   labels
# 0                      0.00   normal
# 1                      0.00   normal
# 2                      0.00  neptune
# 3                      0.01   normal
# 4                      0.00   normal
#
# [5 rows x 42 columns]

# %%
categ = ['protocol_type','service','flag','labels']
# Encode Categorical Columns
le = LabelEncoder()
data[categ] = data[categ].apply(le.fit_transform)

# %%
indexNames = data[ data['labels'] == 35 ].index
# Delete these row indexes from dataFrame
data.drop(indexNames , inplace=True)

# %%
X = data.iloc[:,1:41]
Y = data['labels']

# %%
scaler = Normalizer().fit(X)
X = scaler.transform(X)

# %%
sm = SMOTE(random_state=42,k_neighbors=1)
X_res, y_res = sm.fit_resample(X, Y)

# %%
X_train, X_test,Y_train,Y_test = train_test_split(X_res,y_res, test_size=0.2)

# %%
model = Sequential()
model.add(LSTM(128,input_shape=(40, 1)))  # try using a GRU instead, for fun
model.add(Dropout(0.1))
model.add(Flatten())
model.add(Dense(40))
model.add(Activation('softmax'))

# %%
# define optimizer and objective, compile cnn

model.compile(loss="sparse_categorical_crossentropy", optimizer="adam",metrics=['accuracy'])

# %%
# train
checkpointer = callbacks.ModelCheckpoint(filepath="results/cnn1results/checkpoint-{epoch:02d}.hdf5", verbose=1, save_best_only=True, monitor='val_acc',mode='max')

# %%
history=model.fit(X_train, Y_train, epochs=75,verbose=1,batch_size=500,validation_data=(X_test, Y_test),callbacks=[checkpointer])
# Out:
# Epoch 1/75
# 4525/4527 [============================>.] - ETA: 0s - loss: 1.4081 - accuracy: 0.5437WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 95s 21ms/step - loss: 1.4079 - accuracy: 0.5438 - val_loss: 0.7836 - val_accuracy: 0.7430
# Epoch 2/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.8124 - accuracy: 0.7271WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 91s 20ms/step - loss: 0.8124 - accuracy: 0.7271 - val_loss: 0.5457 - val_accuracy: 0.8177
# Epoch 3/75
# 4525/4527 [============================>.] - ETA: 0s - loss: 0.5985 - accuracy: 0.7955WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 91s 20ms/step - loss: 0.5984 - accuracy: 0.7955 - val_loss: 0.3963 - val_accuracy: 0.8654
# Epoch 4/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.4874 - accuracy: 0.8320WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 88s 19ms/step - loss: 0.4874 - accuracy: 0.8320 - val_loss: 0.4358 - val_accuracy: 0.8403
# Epoch 5/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.4126 - accuracy: 0.8569WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 92s 20ms/step - loss: 0.4126 - accuracy: 0.8569 - val_loss: 0.2794 - val_accuracy: 0.8909
# Epoch 6/75
# 4525/4527 [============================>.] - ETA: 0s - loss: 0.3750 - accuracy: 0.8699WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 91s 20ms/step - loss: 0.3751 - accuracy: 0.8698 - val_loss: 0.5119 - val_accuracy: 0.8231
# Epoch 7/75
# 4525/4527 [============================>.] - ETA: 0s - loss: 0.3269 - accuracy: 0.8857WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 88s 19ms/step - loss: 0.3268 - accuracy: 0.8857 - val_loss: 0.2980 - val_accuracy: 0.8830
# Epoch 8/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.2943 - accuracy: 0.8967WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 88s 19ms/step - loss: 0.2943 - accuracy: 0.8967 - val_loss: 0.2054 - val_accuracy: 0.9302
# Epoch 9/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.2711 - accuracy: 0.9041WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 88s 20ms/step - loss: 0.2711 - accuracy: 0.9041 - val_loss: 0.2932 - val_accuracy: 0.8895
# Epoch 10/75
# 4525/4527 [============================>.] - ETA: 0s - loss: 0.2385 - accuracy: 0.9146WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 89s 20ms/step - loss: 0.2385 - accuracy: 0.9147 - val_loss: 0.2118 - val_accuracy: 0.9251
# Epoch 11/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.2149 - accuracy: 0.9227WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 88s 20ms/step - loss: 0.2149 - accuracy: 0.9227 - val_loss: 0.1592 - val_accuracy: 0.9462
# Epoch 12/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.1686 - accuracy: 0.9382WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 92s 20ms/step - loss: 0.1686 - accuracy: 0.9382 - val_loss: 0.1184 - val_accuracy: 0.9527
# Epoch 13/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.1442 - accuracy: 0.9459WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 90s 20ms/step - loss: 0.1441 - accuracy: 0.9459 - val_loss: 0.1035 - val_accuracy: 0.9600
# Epoch 14/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.1326 - accuracy: 0.9502WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 89s 20ms/step - loss: 0.1326 - accuracy: 0.9502 - val_loss: 0.0964 - val_accuracy: 0.9612
# Epoch 15/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.1180 - accuracy: 0.9548WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 92s 20ms/step - loss: 0.1180 - accuracy: 0.9548 - val_loss: 0.0945 - val_accuracy: 0.9618
# Epoch 16/75
# 4525/4527 [============================>.] - ETA: 0s - loss: 0.1126 - accuracy: 0.9567WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 91s 20ms/step - loss: 0.1126 - accuracy: 0.9567 - val_loss: 0.0868 - val_accuracy: 0.9644
# Epoch 17/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0993 - accuracy: 0.9606WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 91s 20ms/step - loss: 0.0993 - accuracy: 0.9606 - val_loss: 0.0893 - val_accuracy: 0.9595
# Epoch 18/75
# 4525/4527 [============================>.] - ETA: 0s - loss: 0.0945 - accuracy: 0.9624WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 88s 19ms/step - loss: 0.0945 - accuracy: 0.9624 - val_loss: 0.0789 - val_accuracy: 0.9694
# Epoch 19/75
# 4525/4527 [============================>.] - ETA: 0s - loss: 0.0917 - accuracy: 0.9633WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 90s 20ms/step - loss: 0.0917 - accuracy: 0.9634 - val_loss: 0.0794 - val_accuracy: 0.9666
# Epoch 20/75
# 4525/4527 [============================>.] - ETA: 0s - loss: 0.0862 - accuracy: 0.9649WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 92s 20ms/step - loss: 0.0861 - accuracy: 0.9649 - val_loss: 0.0752 - val_accuracy: 0.9689
# Epoch 21/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0842 - accuracy: 0.9659WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 92s 20ms/step - loss: 0.0842 - accuracy: 0.9659 - val_loss: 0.0737 - val_accuracy: 0.9660
# Epoch 22/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0789 - accuracy: 0.9679WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 88s 19ms/step - loss: 0.0789 - accuracy: 0.9679 - val_loss: 0.0633 - val_accuracy: 0.9755
# Epoch 23/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0752 - accuracy: 0.9692WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 88s 20ms/step - loss: 0.0752 - accuracy: 0.9692 - val_loss: 0.0670 - val_accuracy: 0.9728
# Epoch 24/75
# 4525/4527 [============================>.] - ETA: 0s - loss: 0.0730 - accuracy: 0.9700WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 91s 20ms/step - loss: 0.0730 - accuracy: 0.9700 - val_loss: 0.0634 - val_accuracy: 0.9734
# Epoch 25/75
# 4525/4527 [============================>.] - ETA: 0s - loss: 0.0707 - accuracy: 0.9712WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 88s 19ms/step - loss: 0.0707 - accuracy: 0.9712 - val_loss: 0.0573 - val_accuracy: 0.9760
# Epoch 26/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0663 - accuracy: 0.9725WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 88s 19ms/step - loss: 0.0663 - accuracy: 0.9725 - val_loss: 0.0583 - val_accuracy: 0.9748
# Epoch 27/75
# 4525/4527 [============================>.] - ETA: 0s - loss: 0.0644 - accuracy: 0.9733WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 91s 20ms/step - loss: 0.0644 - accuracy: 0.9733 - val_loss: 0.0548 - val_accuracy: 0.9780
# Epoch 28/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0622 - accuracy: 0.9743WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 88s 19ms/step - loss: 0.0622 - accuracy: 0.9743 - val_loss: 0.0666 - val_accuracy: 0.9732
# Epoch 29/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0581 - accuracy: 0.9759WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 88s 19ms/step - loss: 0.0581 - accuracy: 0.9759 - val_loss: 0.0496 - val_accuracy: 0.9783
# Epoch 30/75
# 4525/4527 [============================>.] - ETA: 0s - loss: 0.0554 - accuracy: 0.9769WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 88s 20ms/step - loss: 0.0554 - accuracy: 0.9769 - val_loss: 0.0520 - val_accuracy: 0.9785
# Epoch 31/75
# 4525/4527 [============================>.] - ETA: 0s - loss: 0.0530 - accuracy: 0.9777WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 89s 20ms/step - loss: 0.0530 - accuracy: 0.9777 - val_loss: 0.0483 - val_accuracy: 0.9794
# Epoch 32/75
# 4525/4527 [============================>.] - ETA: 0s - loss: 0.0516 - accuracy: 0.9782WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 88s 20ms/step - loss: 0.0516 - accuracy: 0.9782 - val_loss: 0.0458 - val_accuracy: 0.9795
# Epoch 33/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0509 - accuracy: 0.9786WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 88s 19ms/step - loss: 0.0509 - accuracy: 0.9786 - val_loss: 0.0555 - val_accuracy: 0.9783
# Epoch 34/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0499 - accuracy: 0.9788WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 88s 19ms/step - loss: 0.0499 - accuracy: 0.9788 - val_loss: 0.0423 - val_accuracy: 0.9816
# Epoch 35/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0500 - accuracy: 0.9788WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 91s 20ms/step - loss: 0.0500 - accuracy: 0.9788 - val_loss: 0.0489 - val_accuracy: 0.9804
# Epoch 36/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0479 - accuracy: 0.9795WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 89s 20ms/step - loss: 0.0479 - accuracy: 0.9795 - val_loss: 0.0456 - val_accuracy: 0.9799
# Epoch 37/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0463 - accuracy: 0.9800WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 89s 20ms/step - loss: 0.0463 - accuracy: 0.9800 - val_loss: 0.0457 - val_accuracy: 0.9793
# Epoch 38/75
# 4525/4527 [============================>.] - ETA: 0s - loss: 0.0472 - accuracy: 0.9797WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 89s 20ms/step - loss: 0.0472 - accuracy: 0.9797 - val_loss: 0.0482 - val_accuracy: 0.9801
# Epoch 39/75
# 4525/4527 [============================>.] - ETA: 0s - loss: 0.0459 - accuracy: 0.9802WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 88s 20ms/step - loss: 0.0459 - accuracy: 0.9802 - val_loss: 0.0420 - val_accuracy: 0.9802
# Epoch 40/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0455 - accuracy: 0.9804WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 89s 20ms/step - loss: 0.0455 - accuracy: 0.9804 - val_loss: 0.0425 - val_accuracy: 0.9822
# Epoch 41/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0448 - accuracy: 0.9806WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 92s 20ms/step - loss: 0.0448 - accuracy: 0.9806 - val_loss: 0.0403 - val_accuracy: 0.9819
# Epoch 42/75
# 4525/4527 [============================>.] - ETA: 0s - loss: 0.0439 - accuracy: 0.9810WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 90s 20ms/step - loss: 0.0439 - accuracy: 0.9810 - val_loss: 0.0445 - val_accuracy: 0.9800
# Epoch 43/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0435 - accuracy: 0.9812WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 89s 20ms/step - loss: 0.0435 - accuracy: 0.9812 - val_loss: 0.0424 - val_accuracy: 0.9827
# Epoch 44/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0432 - accuracy: 0.9815WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 92s 20ms/step - loss: 0.0432 - accuracy: 0.9815 - val_loss: 0.0380 - val_accuracy: 0.9824
# Epoch 45/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0424 - accuracy: 0.9815WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 93s 20ms/step - loss: 0.0424 - accuracy: 0.9815 - val_loss: 0.0429 - val_accuracy: 0.9808
# Epoch 46/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0420 - accuracy: 0.9817WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 93s 20ms/step - loss: 0.0420 - accuracy: 0.9817 - val_loss: 0.0425 - val_accuracy: 0.9813
# Epoch 47/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0417 - accuracy: 0.9817WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 90s 20ms/step - loss: 0.0417 - accuracy: 0.9817 - val_loss: 0.0401 - val_accuracy: 0.9815
# Epoch 48/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0411 - accuracy: 0.9820WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 89s 20ms/step - loss: 0.0411 - accuracy: 0.9820 - val_loss: 0.0515 - val_accuracy: 0.9775
# Epoch 49/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0403 - accuracy: 0.9823WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 89s 20ms/step - loss: 0.0403 - accuracy: 0.9823 - val_loss: 0.0402 - val_accuracy: 0.9806
# Epoch 50/75
# 4524/4527 [============================>.] - ETA: 0s - loss: 0.0402 - accuracy: 0.9824WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 89s 20ms/step - loss: 0.0401 - accuracy: 0.9824 - val_loss: 0.0441 - val_accuracy: 0.9804
# Epoch 51/75
# 4525/4527 [============================>.] - ETA: 0s - loss: 0.0395 - accuracy: 0.9826WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 89s 20ms/step - loss: 0.0394 - accuracy: 0.9826 - val_loss: 0.0393 - val_accuracy: 0.9817
# Epoch 52/75
# 4525/4527 [============================>.] - ETA: 0s - loss: 0.0389 - accuracy: 0.9828WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 89s 20ms/step - loss: 0.0389 - accuracy: 0.9828 - val_loss: 0.0398 - val_accuracy: 0.9814
# Epoch 53/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0389 - accuracy: 0.9829WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 89s 20ms/step - loss: 0.0389 - accuracy: 0.9829 - val_loss: 0.0363 - val_accuracy: 0.9844
# Epoch 54/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0385 - accuracy: 0.9829WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 92s 20ms/step - loss: 0.0385 - accuracy: 0.9829 - val_loss: 0.0387 - val_accuracy: 0.9818
# Epoch 55/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0380 - accuracy: 0.9832WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 92s 20ms/step - loss: 0.0380 - accuracy: 0.9832 - val_loss: 0.0383 - val_accuracy: 0.9842
# Epoch 56/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0376 - accuracy: 0.9834WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 89s 20ms/step - loss: 0.0376 - accuracy: 0.9834 - val_loss: 0.0400 - val_accuracy: 0.9826
# Epoch 57/75
# 4525/4527 [============================>.] - ETA: 0s - loss: 0.0370 - accuracy: 0.9836WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 93s 21ms/step - loss: 0.0370 - accuracy: 0.9836 - val_loss: 0.0347 - val_accuracy: 0.9849
# Epoch 58/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0372 - accuracy: 0.9837WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 90s 20ms/step - loss: 0.0372 - accuracy: 0.9837 - val_loss: 0.0441 - val_accuracy: 0.9808
# Epoch 59/75
# 4525/4527 [============================>.] - ETA: 0s - loss: 0.0367 - accuracy: 0.9837WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 89s 20ms/step - loss: 0.0367 - accuracy: 0.9837 - val_loss: 0.0343 - val_accuracy: 0.9842
# Epoch 60/75
# 4525/4527 [============================>.] - ETA: 0s - loss: 0.0358 - accuracy: 0.9842WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 89s 20ms/step - loss: 0.0358 - accuracy: 0.9842 - val_loss: 0.0308 - val_accuracy: 0.9852
# Epoch 61/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0360 - accuracy: 0.9843WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 92s 20ms/step - loss: 0.0360 - accuracy: 0.9843 - val_loss: 0.0378 - val_accuracy: 0.9856
# Epoch 62/75
# 4525/4527 [============================>.] - ETA: 0s - loss: 0.0336 - accuracy: 0.9856WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 89s 20ms/step - loss: 0.0336 - accuracy: 0.9856 - val_loss: 0.0292 - val_accuracy: 0.9878
# Epoch 63/75
# 4525/4527 [============================>.] - ETA: 0s - loss: 0.0321 - accuracy: 0.9860WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 92s 20ms/step - loss: 0.0321 - accuracy: 0.9860 - val_loss: 0.0291 - val_accuracy: 0.9858
# Epoch 64/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0333 - accuracy: 0.9853WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 88s 20ms/step - loss: 0.0333 - accuracy: 0.9853 - val_loss: 0.0429 - val_accuracy: 0.9821
# Epoch 65/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0315 - accuracy: 0.9860WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 88s 20ms/step - loss: 0.0315 - accuracy: 0.9860 - val_loss: 0.0310 - val_accuracy: 0.9862
# Epoch 66/75
# 4525/4527 [============================>.] - ETA: 0s - loss: 0.0305 - accuracy: 0.9864WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 91s 20ms/step - loss: 0.0305 - accuracy: 0.9864 - val_loss: 0.0295 - val_accuracy: 0.9860
# Epoch 67/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0315 - accuracy: 0.9863WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 90s 20ms/step - loss: 0.0315 - accuracy: 0.9863 - val_loss: 0.0320 - val_accuracy: 0.9867
# Epoch 68/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0305 - accuracy: 0.9865WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 89s 20ms/step - loss: 0.0305 - accuracy: 0.9865 - val_loss: 0.0269 - val_accuracy: 0.9876
# Epoch 69/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0290 - accuracy: 0.9872WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 89s 20ms/step - loss: 0.0290 - accuracy: 0.9872 - val_loss: 0.0263 - val_accuracy: 0.9892
# Epoch 70/75
# 4525/4527 [============================>.] - ETA: 0s - loss: 0.0311 - accuracy: 0.9868WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 92s 20ms/step - loss: 0.0311 - accuracy: 0.9868 - val_loss: 0.0291 - val_accuracy: 0.9876
# Epoch 71/75
# 4524/4527 [============================>.] - ETA: 0s - loss: 0.0284 - accuracy: 0.9873WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 89s 20ms/step - loss: 0.0284 - accuracy: 0.9873 - val_loss: 0.0256 - val_accuracy: 0.9894
# Epoch 72/75
# 4525/4527 [============================>.] - ETA: 0s - loss: 0.0292 - accuracy: 0.9871WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 89s 20ms/step - loss: 0.0292 - accuracy: 0.9871 - val_loss: 0.0255 - val_accuracy: 0.9878
# Epoch 73/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0281 - accuracy: 0.9875WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 88s 20ms/step - loss: 0.0281 - accuracy: 0.9875 - val_loss: 0.0276 - val_accuracy: 0.9879
# Epoch 74/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0281 - accuracy: 0.9875WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 90s 20ms/step - loss: 0.0281 - accuracy: 0.9875 - val_loss: 0.0261 - val_accuracy: 0.9874
# Epoch 75/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0289 - accuracy: 0.9873WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 92s 20ms/step - loss: 0.0289 - accuracy: 0.9873 - val_loss: 0.0244 - val_accuracy: 0.9904

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
model.save("results/cnn1results/cnn_model.hdf5")
