# %%
from google.colab import files
files.upload()

# !pip install -q kaggle

# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# This permissions change avoids a warning on Kaggle tool startup.
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-4a2a5ab1-149e-41f0-9f7f-cbbb40f61d77" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4a2a5ab1-149e-41f0-9f7f-cbbb40f61d77">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle (1).json

# %%
# !kaggle datasets download -d kiranmahesh/nslkdd
# Out:
# Downloading nslkdd.zip to /content
#   0% 0.00/2.56M [00:00<?, ?B/s]
# 100% 2.56M/2.56M [00:00<00:00, 113MB/s]

# %%
from zipfile import ZipFile
file_name='/content/nslkdd.zip'
with ZipFile(file_name,'r') as zip:
  zip.extractall()

# %%
from __future__ import print_function
import numpy as np
np.random.seed(1337)  # for reproducibility
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Lambda
from keras.layers import Embedding
from keras.layers import Convolution1D,MaxPooling1D, Flatten
from keras.datasets import imdb
from keras import backend as K
from sklearn.model_selection import train_test_split
import pandas as pd
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import Normalizer
from keras.models import Sequential
from keras.layers import Convolution1D, Dense, Dropout, Flatten, MaxPooling1D
from keras.utils import np_utils
import numpy as np
import h5py
from keras import callbacks
from keras.layers import LSTM, GRU, SimpleRNN
from keras.callbacks import CSVLogger
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
from imblearn.over_sampling import ADASYN
from imblearn.over_sampling import SMOTE

# %%
traindata = pd.read_csv('/content/kdd_train.csv')
testdata = pd.read_csv('/content/kdd_test.csv')

# %%
data= pd.concat([traindata,testdata])
data.head()
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  25
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  26
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# 2                    0.10                    0.05
# 3                    1.00                    0.00
# 4                    1.00                    0.00
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                         0.17                         0.00
# 1                         0.88                         0.00
# 2                         0.00                         0.00
# 3                         0.03                         0.04
# 4                         0.00                         0.00
#
#    dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                  0.00                      0.00                  0.05
# 1                  0.00                      0.00                  0.00
# 2                  1.00                      1.00                  0.00
# 3                  0.03                      0.01                  0.00
# 4                  0.00                      0.00                  0.00
#
#    dst_host_srv_rerror_rate   labels
# 0                      0.00   normal
# 1                      0.00   normal
# 2                      0.00  neptune
# 3                      0.01   normal
# 4                      0.00   normal
#
# [5 rows x 42 columns]

# %%
categ = ['protocol_type','service','flag','labels']
# Encode Categorical Columns
le = LabelEncoder()
data[categ] = data[categ].apply(le.fit_transform)

# %%
indexNames = data[ data['labels'] == 35 ].index
# Delete these row indexes from dataFrame
data.drop(indexNames , inplace=True)

# %%
X = data.iloc[:,1:41]
Y = data['labels']

# %%
scaler = Normalizer().fit(X)
X = scaler.transform(X)

# %%
sm = SMOTE(random_state=42,k_neighbors=1)
X_res, y_res = sm.fit_resample(X, Y)

# %%
X_train, X_test,Y_train,Y_test = train_test_split(X_res,y_res, test_size=0.2)

# %%
cnn = Sequential()
cnn.add(Convolution1D(128, 3 ,activation="relu",input_shape=(40, 1)))
cnn.add(MaxPooling1D(2))
cnn.add(Flatten())
cnn.add(Dense(128, activation="relu"))
cnn.add(Dropout(0.5))
cnn.add(Dense(40, activation="softmax"))

# %%
cnn.compile(loss="sparse_categorical_crossentropy", optimizer="adam",metrics=['accuracy'])

# %%
checkpointer = callbacks.ModelCheckpoint(filepath="results/cnn1results/checkpoint-{epoch:02d}.hdf5", verbose=1, save_best_only=True, monitor='val_acc',mode='max')

# %%
history=cnn.fit(X_train, Y_train, epochs=75,verbose=1,batch_size=500,validation_data=(X_test, Y_test),callbacks=[checkpointer])
# Out:
# Epoch 1/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.7509 - accuracy: 0.7638WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 255s 56ms/step - loss: 0.7508 - accuracy: 0.7638 - val_loss: 0.2842 - val_accuracy: 0.9092
# Epoch 2/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.3362 - accuracy: 0.8868WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 255s 56ms/step - loss: 0.3362 - accuracy: 0.8868 - val_loss: 0.1764 - val_accuracy: 0.9500
# Epoch 3/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.2533 - accuracy: 0.9144WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 255s 56ms/step - loss: 0.2533 - accuracy: 0.9144 - val_loss: 0.1376 - val_accuracy: 0.9560
# Epoch 4/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.2105 - accuracy: 0.9283WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 243s 54ms/step - loss: 0.2105 - accuracy: 0.9283 - val_loss: 0.1211 - val_accuracy: 0.9628
# Epoch 5/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.1864 - accuracy: 0.9359WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 245s 54ms/step - loss: 0.1864 - accuracy: 0.9359 - val_loss: 0.1089 - val_accuracy: 0.9643
# Epoch 6/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.1700 - accuracy: 0.9412WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 244s 54ms/step - loss: 0.1700 - accuracy: 0.9412 - val_loss: 0.0986 - val_accuracy: 0.9672
# Epoch 7/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.1579 - accuracy: 0.9450WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 245s 54ms/step - loss: 0.1579 - accuracy: 0.9450 - val_loss: 0.0977 - val_accuracy: 0.9619
# Epoch 8/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.1493 - accuracy: 0.9475WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 244s 54ms/step - loss: 0.1493 - accuracy: 0.9475 - val_loss: 0.0854 - val_accuracy: 0.9701
# Epoch 9/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.1401 - accuracy: 0.9506WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 237s 52ms/step - loss: 0.1401 - accuracy: 0.9506 - val_loss: 0.0832 - val_accuracy: 0.9718
# Epoch 10/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.1336 - accuracy: 0.9525WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 239s 53ms/step - loss: 0.1336 - accuracy: 0.9525 - val_loss: 0.0789 - val_accuracy: 0.9713
# Epoch 11/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.1271 - accuracy: 0.9547WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 243s 54ms/step - loss: 0.1271 - accuracy: 0.9547 - val_loss: 0.0753 - val_accuracy: 0.9727
# Epoch 12/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.1221 - accuracy: 0.9566WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 245s 54ms/step - loss: 0.1221 - accuracy: 0.9566 - val_loss: 0.0693 - val_accuracy: 0.9729
# Epoch 13/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.1172 - accuracy: 0.9581WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 243s 54ms/step - loss: 0.1172 - accuracy: 0.9581 - val_loss: 0.0691 - val_accuracy: 0.9757
# Epoch 14/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.1122 - accuracy: 0.9598WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 239s 53ms/step - loss: 0.1122 - accuracy: 0.9598 - val_loss: 0.0671 - val_accuracy: 0.9733
# Epoch 15/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.1088 - accuracy: 0.9608WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 235s 52ms/step - loss: 0.1088 - accuracy: 0.9608 - val_loss: 0.0683 - val_accuracy: 0.9732
# Epoch 16/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.1049 - accuracy: 0.9620WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 232s 51ms/step - loss: 0.1049 - accuracy: 0.9620 - val_loss: 0.0646 - val_accuracy: 0.9740
# Epoch 17/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.1017 - accuracy: 0.9631WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 233s 52ms/step - loss: 0.1017 - accuracy: 0.9631 - val_loss: 0.0640 - val_accuracy: 0.9775
# Epoch 18/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0974 - accuracy: 0.9646WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 233s 51ms/step - loss: 0.0974 - accuracy: 0.9646 - val_loss: 0.0597 - val_accuracy: 0.9757
# Epoch 19/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0953 - accuracy: 0.9655WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 241s 53ms/step - loss: 0.0953 - accuracy: 0.9655 - val_loss: 0.0600 - val_accuracy: 0.9754
# Epoch 20/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0919 - accuracy: 0.9665WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 240s 53ms/step - loss: 0.0919 - accuracy: 0.9665 - val_loss: 0.0533 - val_accuracy: 0.9787
# Epoch 21/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0893 - accuracy: 0.9674WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 242s 53ms/step - loss: 0.0893 - accuracy: 0.9674 - val_loss: 0.0554 - val_accuracy: 0.9798
# Epoch 22/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0875 - accuracy: 0.9679WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 245s 54ms/step - loss: 0.0875 - accuracy: 0.9679 - val_loss: 0.0508 - val_accuracy: 0.9792
# Epoch 23/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0843 - accuracy: 0.9691WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 243s 54ms/step - loss: 0.0843 - accuracy: 0.9691 - val_loss: 0.0525 - val_accuracy: 0.9790
# Epoch 24/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0823 - accuracy: 0.9698WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 243s 54ms/step - loss: 0.0823 - accuracy: 0.9698 - val_loss: 0.0535 - val_accuracy: 0.9792
# Epoch 25/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0802 - accuracy: 0.9705WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 242s 53ms/step - loss: 0.0802 - accuracy: 0.9705 - val_loss: 0.0505 - val_accuracy: 0.9795
# Epoch 26/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0779 - accuracy: 0.9714WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 243s 54ms/step - loss: 0.0779 - accuracy: 0.9714 - val_loss: 0.0488 - val_accuracy: 0.9822
# Epoch 27/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0762 - accuracy: 0.9720WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 243s 54ms/step - loss: 0.0762 - accuracy: 0.9720 - val_loss: 0.0490 - val_accuracy: 0.9816
# Epoch 28/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0742 - accuracy: 0.9728WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 245s 54ms/step - loss: 0.0742 - accuracy: 0.9728 - val_loss: 0.0485 - val_accuracy: 0.9810
# Epoch 29/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0728 - accuracy: 0.9731WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 237s 52ms/step - loss: 0.0728 - accuracy: 0.9731 - val_loss: 0.0480 - val_accuracy: 0.9803
# Epoch 30/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0713 - accuracy: 0.9737WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 235s 52ms/step - loss: 0.0713 - accuracy: 0.9737 - val_loss: 0.0435 - val_accuracy: 0.9813
# Epoch 31/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0694 - accuracy: 0.9744WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 240s 53ms/step - loss: 0.0694 - accuracy: 0.9744 - val_loss: 0.0455 - val_accuracy: 0.9805
# Epoch 32/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0679 - accuracy: 0.9749WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 241s 53ms/step - loss: 0.0679 - accuracy: 0.9749 - val_loss: 0.0420 - val_accuracy: 0.9848
# Epoch 33/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0666 - accuracy: 0.9754WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 244s 54ms/step - loss: 0.0666 - accuracy: 0.9754 - val_loss: 0.0422 - val_accuracy: 0.9827
# Epoch 34/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0650 - accuracy: 0.9760WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 237s 52ms/step - loss: 0.0650 - accuracy: 0.9760 - val_loss: 0.0383 - val_accuracy: 0.9850
# Epoch 35/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0640 - accuracy: 0.9763WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 250s 55ms/step - loss: 0.0640 - accuracy: 0.9763 - val_loss: 0.0423 - val_accuracy: 0.9832
# Epoch 36/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0630 - accuracy: 0.9769WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 254s 56ms/step - loss: 0.0630 - accuracy: 0.9769 - val_loss: 0.0408 - val_accuracy: 0.9836
# Epoch 37/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0622 - accuracy: 0.9769WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 252s 56ms/step - loss: 0.0622 - accuracy: 0.9769 - val_loss: 0.0366 - val_accuracy: 0.9858
# Epoch 38/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0604 - accuracy: 0.9778WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 252s 56ms/step - loss: 0.0604 - accuracy: 0.9778 - val_loss: 0.0407 - val_accuracy: 0.9866
# Epoch 39/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0594 - accuracy: 0.9781WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 255s 56ms/step - loss: 0.0594 - accuracy: 0.9781 - val_loss: 0.0360 - val_accuracy: 0.9863
# Epoch 40/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0581 - accuracy: 0.9787WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 255s 56ms/step - loss: 0.0581 - accuracy: 0.9787 - val_loss: 0.0380 - val_accuracy: 0.9858
# Epoch 41/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0574 - accuracy: 0.9789WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 250s 55ms/step - loss: 0.0574 - accuracy: 0.9789 - val_loss: 0.0337 - val_accuracy: 0.9871
# Epoch 42/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0563 - accuracy: 0.9793WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 235s 52ms/step - loss: 0.0563 - accuracy: 0.9793 - val_loss: 0.0328 - val_accuracy: 0.9876
# Epoch 43/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0550 - accuracy: 0.9797WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 233s 51ms/step - loss: 0.0550 - accuracy: 0.9797 - val_loss: 0.0332 - val_accuracy: 0.9874
# Epoch 44/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0546 - accuracy: 0.9799WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 235s 52ms/step - loss: 0.0546 - accuracy: 0.9799 - val_loss: 0.0329 - val_accuracy: 0.9879
# Epoch 45/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0541 - accuracy: 0.9800WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 234s 52ms/step - loss: 0.0541 - accuracy: 0.9800 - val_loss: 0.0329 - val_accuracy: 0.9875
# Epoch 46/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0530 - accuracy: 0.9805WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 234s 52ms/step - loss: 0.0530 - accuracy: 0.9805 - val_loss: 0.0335 - val_accuracy: 0.9889
# Epoch 47/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0519 - accuracy: 0.9810WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 238s 53ms/step - loss: 0.0519 - accuracy: 0.9810 - val_loss: 0.0310 - val_accuracy: 0.9882
# Epoch 48/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0510 - accuracy: 0.9813WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 234s 52ms/step - loss: 0.0510 - accuracy: 0.9813 - val_loss: 0.0307 - val_accuracy: 0.9883
# Epoch 49/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0507 - accuracy: 0.9814WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 235s 52ms/step - loss: 0.0507 - accuracy: 0.9814 - val_loss: 0.0350 - val_accuracy: 0.9860
# Epoch 50/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0500 - accuracy: 0.9817WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 232s 51ms/step - loss: 0.0500 - accuracy: 0.9817 - val_loss: 0.0314 - val_accuracy: 0.9878
# Epoch 51/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0495 - accuracy: 0.9818WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 231s 51ms/step - loss: 0.0495 - accuracy: 0.9818 - val_loss: 0.0312 - val_accuracy: 0.9878
# Epoch 52/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0486 - accuracy: 0.9821WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 235s 52ms/step - loss: 0.0486 - accuracy: 0.9821 - val_loss: 0.0310 - val_accuracy: 0.9877
# Epoch 53/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0481 - accuracy: 0.9823WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 236s 52ms/step - loss: 0.0481 - accuracy: 0.9823 - val_loss: 0.0338 - val_accuracy: 0.9865
# Epoch 54/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0476 - accuracy: 0.9826WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 238s 53ms/step - loss: 0.0476 - accuracy: 0.9826 - val_loss: 0.0302 - val_accuracy: 0.9888
# Epoch 55/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0475 - accuracy: 0.9825WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 239s 53ms/step - loss: 0.0475 - accuracy: 0.9825 - val_loss: 0.0313 - val_accuracy: 0.9887
# Epoch 56/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0470 - accuracy: 0.9828WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 239s 53ms/step - loss: 0.0470 - accuracy: 0.9828 - val_loss: 0.0313 - val_accuracy: 0.9872
# Epoch 57/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0465 - accuracy: 0.9829WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 244s 54ms/step - loss: 0.0465 - accuracy: 0.9829 - val_loss: 0.0296 - val_accuracy: 0.9886
# Epoch 58/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0463 - accuracy: 0.9831WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 250s 55ms/step - loss: 0.0463 - accuracy: 0.9831 - val_loss: 0.0285 - val_accuracy: 0.9894
# Epoch 59/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0452 - accuracy: 0.9834WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 255s 56ms/step - loss: 0.0452 - accuracy: 0.9834 - val_loss: 0.0275 - val_accuracy: 0.9894
# Epoch 60/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0456 - accuracy: 0.9832WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 255s 56ms/step - loss: 0.0456 - accuracy: 0.9832 - val_loss: 0.0288 - val_accuracy: 0.9890
# Epoch 61/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0448 - accuracy: 0.9837WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 254s 56ms/step - loss: 0.0448 - accuracy: 0.9837 - val_loss: 0.0285 - val_accuracy: 0.9884
# Epoch 62/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0442 - accuracy: 0.9837WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 254s 56ms/step - loss: 0.0442 - accuracy: 0.9837 - val_loss: 0.0278 - val_accuracy: 0.9887
# Epoch 63/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0437 - accuracy: 0.9839WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 254s 56ms/step - loss: 0.0437 - accuracy: 0.9839 - val_loss: 0.0299 - val_accuracy: 0.9876
# Epoch 64/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0434 - accuracy: 0.9841WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 250s 55ms/step - loss: 0.0434 - accuracy: 0.9841 - val_loss: 0.0282 - val_accuracy: 0.9895
# Epoch 65/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0430 - accuracy: 0.9841WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 255s 56ms/step - loss: 0.0430 - accuracy: 0.9841 - val_loss: 0.0281 - val_accuracy: 0.9887
# Epoch 66/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0427 - accuracy: 0.9843WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 255s 56ms/step - loss: 0.0427 - accuracy: 0.9843 - val_loss: 0.0263 - val_accuracy: 0.9907
# Epoch 67/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0423 - accuracy: 0.9845WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 252s 56ms/step - loss: 0.0423 - accuracy: 0.9845 - val_loss: 0.0284 - val_accuracy: 0.9896
# Epoch 68/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0418 - accuracy: 0.9846WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 249s 55ms/step - loss: 0.0418 - accuracy: 0.9846 - val_loss: 0.0273 - val_accuracy: 0.9890
# Epoch 69/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0415 - accuracy: 0.9848WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 250s 55ms/step - loss: 0.0415 - accuracy: 0.9848 - val_loss: 0.0264 - val_accuracy: 0.9901
# Epoch 70/75
# 4527/4527 [==============================] - ETA: 0s - loss: 0.0418 - accuracy: 0.9847WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 255s 56ms/step - loss: 0.0418 - accuracy: 0.9847 - val_loss: 0.0273 - val_accuracy: 0.9899
# Epoch 71/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0406 - accuracy: 0.9850WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 255s 56ms/step - loss: 0.0406 - accuracy: 0.9850 - val_loss: 0.0275 - val_accuracy: 0.9896
# Epoch 72/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0407 - accuracy: 0.9850WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 253s 56ms/step - loss: 0.0407 - accuracy: 0.9850 - val_loss: 0.0253 - val_accuracy: 0.9898
# Epoch 73/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0403 - accuracy: 0.9852WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 255s 56ms/step - loss: 0.0403 - accuracy: 0.9852 - val_loss: 0.0253 - val_accuracy: 0.9904
# Epoch 74/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0399 - accuracy: 0.9853WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 254s 56ms/step - loss: 0.0399 - accuracy: 0.9853 - val_loss: 0.0267 - val_accuracy: 0.9900
# Epoch 75/75
# 4526/4527 [============================>.] - ETA: 0s - loss: 0.0396 - accuracy: 0.9855WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4527/4527 [==============================] - 257s 57ms/step - loss: 0.0396 - accuracy: 0.9855 - val_loss: 0.0265 - val_accuracy: 0.9899

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
cnn.save("results/cnn1results/cnn_model.hdf5")
