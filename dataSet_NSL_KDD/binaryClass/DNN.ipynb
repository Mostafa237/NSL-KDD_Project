# %%
from __future__ import print_function
import numpy as np
np.random.seed(1337)  # for reproducibility
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Lambda
from keras.layers import Embedding
from keras.layers import Convolution1D,MaxPooling1D, Flatten
from keras.datasets import imdb
from keras import backend as K
from sklearn.model_selection import train_test_split
import pandas as pd
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import Normalizer
from keras.models import Sequential
from keras.layers import Convolution1D, Dense, Dropout, Flatten, MaxPooling1D
from keras.utils import np_utils
import numpy as np
import h5py
from keras import callbacks
from keras.layers import LSTM, GRU, SimpleRNN
from keras.callbacks import CSVLogger
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# %%
from google.colab import files
files.upload()

# !pip install -q kaggle

# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# This permissions change avoids a warning on Kaggle tool startup.
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-c7025eb6-be53-4fa7-a20c-c692d48afef3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c7025eb6-be53-4fa7-a20c-c692d48afef3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle (1).json

# %%
# !kaggle datasets download -d kiranmahesh/nslkdd
# Out:
# nslkdd.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
from zipfile import ZipFile
file_name='/content/nslkdd.zip'
with ZipFile(file_name,'r') as zip:
  zip.extractall()

# %%
traindata = pd.read_csv('/content/kdd_train.csv')
testdata = pd.read_csv('/content/kdd_test.csv')

# %%
data = pd.concat([traindata,testdata])
data.head()
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  25
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  26
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# 2                    0.10                    0.05
# 3                    1.00                    0.00
# 4                    1.00                    0.00
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                         0.17                         0.00
# 1                         0.88                         0.00
# 2                         0.00                         0.00
# 3                         0.03                         0.04
# 4                         0.00                         0.00
#
#    dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                  0.00                      0.00                  0.05
# 1                  0.00                      0.00                  0.00
# 2                  1.00                      1.00                  0.00
# 3                  0.03                      0.01                  0.00
# 4                  0.00                      0.00                  0.00
#
#    dst_host_srv_rerror_rate   labels
# 0                      0.00   normal
# 1                      0.00   normal
# 2                      0.00  neptune
# 3                      0.01   normal
# 4                      0.00   normal
#
# [5 rows x 42 columns]

# %%
categ = ['protocol_type','service','flag']
# Encode Categorical Columns
le = LabelEncoder()
data[categ] = data[categ].apply(le.fit_transform)
#data[categ] = testdata[categ].apply(le.fit_transform)

# %%
labels=[]
for i in data['labels']:
  if i=='normal':
    labels.append(0)
  else:
    labels.append(1)
data['labels']=labels

# %%
X = data.iloc[:,1:41]
Y = data['labels']

# %%
scaler = Normalizer().fit(X)
X = scaler.transform(X)

# %%
X_train, X_test,Y_train,Y_test = train_test_split(X,Y, test_size=0.2)

# %%
# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0],X_train.shape[1],1))
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))

# %%
model = Sequential()
model.add(Dense(128,input_shape=(40, 1),activation='relu'))  
model.add(Dropout(0.01))
model.add(Flatten())
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
model.compile(loss="binary_crossentropy", optimizer="adam",metrics=['accuracy'])

# %%
checkpointer = callbacks.ModelCheckpoint(filepath="results/cnn1results/checkpoint-{epoch:02d}.hdf5", verbose=1, save_best_only=True, monitor='val_acc',mode='max')

# %%
history=model.fit(X_train, Y_train, epochs=75,verbose=1,batch_size=500,validation_data=(X_test, Y_test),callbacks=[checkpointer])
# Out:
# Epoch 1/75
# 235/238 [============================>.] - ETA: 0s - loss: 0.3875 - accuracy: 0.8735WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 13ms/step - loss: 0.3862 - accuracy: 0.8735 - val_loss: 0.2702 - val_accuracy: 0.8794
# Epoch 2/75
# 233/238 [============================>.] - ETA: 0s - loss: 0.2450 - accuracy: 0.8946WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 3s 12ms/step - loss: 0.2444 - accuracy: 0.8949 - val_loss: 0.2299 - val_accuracy: 0.9051
# Epoch 3/75
# 237/238 [============================>.] - ETA: 0s - loss: 0.2213 - accuracy: 0.9085WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 3s 13ms/step - loss: 0.2212 - accuracy: 0.9086 - val_loss: 0.2166 - val_accuracy: 0.9131
# Epoch 4/75
# 238/238 [==============================] - ETA: 0s - loss: 0.2129 - accuracy: 0.9150WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 3s 13ms/step - loss: 0.2129 - accuracy: 0.9150 - val_loss: 0.2116 - val_accuracy: 0.9167
# Epoch 5/75
# 237/238 [============================>.] - ETA: 0s - loss: 0.2094 - accuracy: 0.9183WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 3s 12ms/step - loss: 0.2093 - accuracy: 0.9183 - val_loss: 0.2104 - val_accuracy: 0.9102
# Epoch 6/75
# 235/238 [============================>.] - ETA: 0s - loss: 0.2074 - accuracy: 0.9197WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 3s 14ms/step - loss: 0.2074 - accuracy: 0.9197 - val_loss: 0.2078 - val_accuracy: 0.9169
# Epoch 7/75
# 236/238 [============================>.] - ETA: 0s - loss: 0.2059 - accuracy: 0.9210WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 3s 11ms/step - loss: 0.2061 - accuracy: 0.9210 - val_loss: 0.2059 - val_accuracy: 0.9175
# Epoch 8/75
# 238/238 [==============================] - ETA: 0s - loss: 0.2052 - accuracy: 0.9224WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 3s 12ms/step - loss: 0.2052 - accuracy: 0.9224 - val_loss: 0.2047 - val_accuracy: 0.9257
# Epoch 9/75
# 237/238 [============================>.] - ETA: 0s - loss: 0.2043 - accuracy: 0.9231WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 3s 13ms/step - loss: 0.2045 - accuracy: 0.9230 - val_loss: 0.2043 - val_accuracy: 0.9257
# Epoch 10/75
# 237/238 [============================>.] - ETA: 0s - loss: 0.2043 - accuracy: 0.9228WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 3s 12ms/step - loss: 0.2043 - accuracy: 0.9229 - val_loss: 0.2048 - val_accuracy: 0.9251
# Epoch 11/75
# 236/238 [============================>.] - ETA: 0s - loss: 0.2034 - accuracy: 0.9249WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 2s 10ms/step - loss: 0.2034 - accuracy: 0.9248 - val_loss: 0.2036 - val_accuracy: 0.9257
# Epoch 12/75
# 235/238 [============================>.] - ETA: 0s - loss: 0.2031 - accuracy: 0.9241WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 3s 11ms/step - loss: 0.2031 - accuracy: 0.9242 - val_loss: 0.2030 - val_accuracy: 0.9275
# Epoch 13/75
# 237/238 [============================>.] - ETA: 0s - loss: 0.2026 - accuracy: 0.9242WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 3s 12ms/step - loss: 0.2025 - accuracy: 0.9243 - val_loss: 0.2022 - val_accuracy: 0.9207
# Epoch 14/75
# 237/238 [============================>.] - ETA: 0s - loss: 0
ARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 2s 7ms/step - loss: 0.1587 - accuracy: 0.9450 - val_loss: 0.1552 - val_accuracy: 0.9450
# Epoch 62/75
# 235/238 [============================>.] - ETA: 0s - loss: 0.1579 - accuracy: 0.9459WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 2s 8ms/step - loss: 0.1581 - accuracy: 0.9458 - val_loss: 0.1542 - val_accuracy: 0.9457
# Epoch 63/75
# 234/238 [============================>.] - ETA: 0s - loss: 0.1571 - accuracy: 0.9459WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 2s 8ms/step - loss: 0.1576 - accuracy: 0.9458 - val_loss: 0.1533 - val_accuracy: 0.9462
# Epoch 64/75
# 236/238 [============================>.] - ETA: 0s - loss: 0.1570 - accuracy: 0.9457WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 2s 10ms/step - loss: 0.1569 - accuracy: 0.9457 - val_loss: 0.1530 - val_accuracy: 0.9465
# Epoch 65/75
# 234/238 [============================>.] - ETA: 0s - loss: 0.1569 - accuracy: 0.9459WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 3s 11ms/step - loss: 0.1564 - accuracy: 0.9461 - val_loss: 0.1550 - val_accuracy: 0.9463
# Epoch 66/75
# 238/238 [==============================] - ETA: 0s - loss: 0.1561 - accuracy: 0.9456WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 2s 9ms/step - loss: 0.1561 - accuracy: 0.9456 - val_loss: 0.1551 - val_accuracy: 0.9470
# Epoch 67/75
# 231/238 [============================>.] - ETA: 0s - loss: 0.1546 - accuracy: 0.9466WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 2s 8ms/step - loss: 0.1549 - accuracy: 0.9463 - val_loss: 0.1513 - val_accuracy: 0.9471
# Epoch 68/75
# 237/238 [============================>.] - ETA: 0s - loss: 0.1546 - accuracy: 0.9462WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 2s 8ms/step - loss: 0.1546 - accuracy: 0.9462 - val_loss: 0.1509 - val_accuracy: 0.9461
# Epoch 69/75
# 237/238 [============================>.] - ETA: 0s - loss: 0.1545 - accuracy: 0.9462WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 2s 7ms/step - loss: 0.1546 - accuracy: 0.9461 - val_loss: 0.1501 - val_accuracy: 0.9465
# Epoch 70/75
# 237/238 [============================>.] - ETA: 0s - loss: 0.1547 - accuracy: 0.9461WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 2s 7ms/step - loss: 0.1547 - accuracy: 0.9461 - val_loss: 0.1493 - val_accuracy: 0.9478
# Epoch 71/75
# 234/238 [============================>.] - ETA: 0s - loss: 0.1539 - accuracy: 0.9466WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 2s 7ms/step - loss: 0.1536 - accuracy: 0.9467 - val_loss: 0.1500 - val_accuracy: 0.9477
# Epoch 72/75
# 231/238 [============================>.] - ETA: 0s - loss: 0.1528 - accuracy: 0.9464WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 2s 7ms/step - loss: 0.1533 - accuracy: 0.9463 - val_loss: 0.1487 - val_accuracy: 0.9459
# Epoch 73/75
# 234/238 [============================>.] - ETA: 0s - loss: 0.1533 - accuracy: 0.9462WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 2s 8ms/step - loss: 0.1532 - accuracy: 0.9462 - val_loss: 0.1480 - val_accuracy: 0.9472
# Epoch 74/75
# 235/238 [============================>.] - ETA: 0s - loss: 0.1533 - accuracy: 0.9467WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 2s 7ms/step - loss: 0.1530 - accuracy: 0.9468 - val_loss: 0.1494 - val_accuracy: 0.9474
# Epoch 75/75
# 233/238 [============================>.] - ETA: 0s - loss: 0.1527 - accuracy: 0.9467WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 2s 8ms/step - loss: 0.1523 - accuracy: 0.9469 - val_loss: 0.1479 - val_accuracy: 0.9455

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
model.save("results/cnn1results/cnn_model.hdf5")
