# %%
from __future__ import print_function
import numpy as np
np.random.seed(1337)  # for reproducibility
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Lambda
from keras.layers import Embedding
from keras.layers import Convolution1D,MaxPooling1D, Flatten
from keras.datasets import imdb
from keras import backend as K
from sklearn.model_selection import train_test_split
import pandas as pd
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import Normalizer
from keras.models import Sequential
from keras.layers import Convolution1D, Dense, Dropout, Flatten, MaxPooling1D
from keras.utils import np_utils
import numpy as np
import h5py
from keras import callbacks
from keras.layers import LSTM, GRU, SimpleRNN
from keras.callbacks import CSVLogger
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# %%
from google.colab import files
files.upload()

# !pip install -q kaggle

# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# This permissions change avoids a warning on Kaggle tool startup.
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-10c7d6d4-e07a-4552-b667-b934b93330ba" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-10c7d6d4-e07a-4552-b667-b934b93330ba">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle (2).json

# %%
# !kaggle datasets download -d kiranmahesh/nslkdd
# Out:
# nslkdd.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
from zipfile import ZipFile
file_name='/content/nslkdd.zip'
with ZipFile(file_name,'r') as zip:
  zip.extractall()

# %%
traindata = pd.read_csv('/content/kdd_train.csv')
testdata = pd.read_csv('/content/kdd_test.csv')

# %%
traindata = pd.read_csv('kdd_train.csv')
testdata = pd.read_csv('kdd_test.csv')

# %%
data = pd.concat([traindata,testdata])
data.head()
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  25
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  26
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# 2                    0.10                    0.05
# 3                    1.00                    0.00
# 4                    1.00                    0.00
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                         0.17                         0.00
# 1                         0.88                         0.00
# 2                         0.00                         0.00
# 3                         0.03                         0.04
# 4                         0.00                         0.00
#
#    dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                  0.00                      0.00                  0.05
# 1                  0.00                      0.00                  0.00
# 2                  1.00                      1.00                  0.00
# 3                  0.03                      0.01                  0.00
# 4                  0.00                      0.00                  0.00
#
#    dst_host_srv_rerror_rate   labels
# 0                      0.00   normal
# 1                      0.00   normal
# 2                      0.00  neptune
# 3                      0.01   normal
# 4                      0.00   normal
#
# [5 rows x 42 columns]

# %%
categ = ['protocol_type','service','flag']
# Encode Categorical Columns
le = LabelEncoder()
data[categ] = data[categ].apply(le.fit_transform)
#data[categ] = testdata[categ].apply(le.fit_transform)

# %%
labels=[]
for i in data['labels']:
  if i=='normal':
    labels.append(0)
  else:
    labels.append(1)
data['labels']=labels

# %%
X = data.iloc[:,1:41]
Y = data['labels']

# %%
scaler = Normalizer().fit(X)
X = scaler.transform(X)

# %%
X_train, X_test,Y_train,Y_test = train_test_split(X,Y, test_size=0.2)

# %%
# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0],X_train.shape[1],1))
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))

# %%
model = Sequential()
model.add(GRU(128,input_shape=(40,1)))
model.add(Dropout(0.1))
model.add(Flatten())
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
model.compile(loss="binary_crossentropy", optimizer="adam",metrics=['accuracy'])

# %%
checkpointer = callbacks.ModelCheckpoint(filepath="results/cnn1results/checkpoint-{epoch:02d}.hdf5", verbose=1, save_best_only=True, monitor='val_acc',mode='max')

# %%
history=model.fit(X_train, Y_train, epochs=75,verbose=1,batch_size=500,validation_data=(X_test, Y_test),callbacks=[checkpointer])
# Out:
# Epoch 1/75
# 237/238 [============================>.] - ETA: 0s - loss: 0.4171 - accuracy: 0.8127WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 19s 38ms/step - loss: 0.4168 - accuracy: 0.8129 - val_loss: 0.2861 - val_accuracy: 0.8754
# Epoch 2/75
# 237/238 [============================>.] - ETA: 0s - loss: 0.2607 - accuracy: 0.8974WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 8s 32ms/step - loss: 0.2607 - accuracy: 0.8974 - val_loss: 0.2239 - val_accuracy: 0.9072
# Epoch 3/75
# 236/238 [============================>.] - ETA: 0s - loss: 0.2355 - accuracy: 0.9087WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 7s 30ms/step - loss: 0.2351 - accuracy: 0.9088 - val_loss: 0.2045 - val_accuracy: 0.9202
# Epoch 4/75
# 237/238 [============================>.] - ETA: 0s - loss: 0.2165 - accuracy: 0.9162WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 6s 25ms/step - loss: 0.2165 - accuracy: 0.9162 - val_loss: 0.2088 - val_accuracy: 0.9226
# Epoch 5/75
# 238/238 [==============================] - ETA: 0s - loss: 0.2099 - accuracy: 0.9189WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 6s 24ms/step - loss: 0.2099 - accuracy: 0.9189 - val_loss: 0.1953 - val_accuracy: 0.9242
# Epoch 6/75
# 236/238 [============================>.] - ETA: 0s - loss: 0.2028 - accuracy: 0.9219WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 6s 25ms/step - loss: 0.2029 - accuracy: 0.9219 - val_loss: 0.2215 - val_accuracy: 0.9069
# Epoch 7/75
# 238/238 [==============================] - ETA: 0s - loss: 0.2046 - accuracy: 0.9219WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 6s 25ms/step - loss: 0.2046 - accuracy: 0.9219 - val_loss: 0.1883 - val_accuracy: 0.9274
# Epoch 8/75
# 238/238 [==============================] - ETA: 0s - loss: 0.1943 - accuracy: 0.9268WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 6s 25ms/step - loss: 0.1943 - accuracy: 0.9268 - val_loss: 0.1811 - val_accuracy: 0.9316
# Epoch 9/75
# 238/238 [==============================] - ETA: 0s - loss: 0.1890 - accuracy: 0.9291WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 6s 24ms/step - loss: 0.1890 - accuracy: 0.9291 - val_loss: 0.1795 - val_accuracy: 0.9307
# Epoch 10/75
# 237/238 [============================>.] - ETA: 0s - loss: 0.1854 - accuracy: 0.9311WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 6s 24ms/step - loss: 0.1853 - accuracy: 0.9311 - val_loss: 0.1752 - val_accuracy: 0.9383
# Epoch 11/75
# 237/238 [============================>.] - ETA: 0s - loss: 0.1834 - accuracy: 0.9320WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 6s 24ms/step - loss: 0.1832 - accuracy: 0.9321 - val_loss: 0.1711 - val_accuracy: 0.9409
# Epoch 12/75
# 236/238 [============================>.] - ETA: 0s - loss: 0.1801 - accuracy: 0.9336WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 6s 25ms/step - loss: 0.1800 - accuracy: 0.9337 - val_loss: 0.1710 - val_accuracy: 0.9323
# Epoch 13/75
# 236/238 [============================>.] - ETA: 0s - loss: 0.1697 - accuracy: 0.9394WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] -