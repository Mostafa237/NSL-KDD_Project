# %%
from __future__ import print_function
import numpy as np
np.random.seed(1337)  # for reproducibility
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Lambda
from keras.layers import Embedding
from keras.layers import Convolution1D,MaxPooling1D, Flatten
from keras.datasets import imdb
from keras import backend as K
from sklearn.model_selection import train_test_split
import pandas as pd
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import Normalizer
from keras.models import Sequential
from keras.layers import Convolution1D, Dense, Dropout, Flatten, MaxPooling1D
from keras.utils import np_utils
import numpy as np
import h5py
from keras import callbacks
from keras.layers import LSTM, GRU, SimpleRNN
from keras.callbacks import CSVLogger
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# %%
from google.colab import files
files.upload()

# !pip install -q kaggle

# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# This permissions change avoids a warning on Kaggle tool startup.
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-870015eb-2f1a-4ebf-809f-0141bcbccd7a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-870015eb-2f1a-4ebf-809f-0141bcbccd7a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %%
# !kaggle datasets download -d kiranmahesh/nslkdd
# Out:
# Downloading nslkdd.zip to /content
#   0% 0.00/2.56M [00:00<?, ?B/s]
# 100% 2.56M/2.56M [00:00<00:00, 84.8MB/s]

# %%
from zipfile import ZipFile
file_name='/content/nslkdd.zip'
with ZipFile(file_name,'r') as zip:
  zip.extractall()

# %%
traindata = pd.read_csv('/content/kdd_train.csv')
testdata = pd.read_csv('/content/kdd_test.csv')

# %%
data = pd.concat([traindata,testdata])
data.head()
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  25
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  26
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# 2                    0.10                    0.05
# 3                    1.00                    0.00
# 4                    1.00                    0.00
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                         0.17                         0.00
# 1                         0.88                         0.00
# 2                         0.00                         0.00
# 3                         0.03                         0.04
# 4                         0.00                         0.00
#
#    dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                  0.00                      0.00                  0.05
# 1                  0.00                      0.00                  0.00
# 2                  1.00                      1.00                  0.00
# 3                  0.03                      0.01                  0.00
# 4                  0.00                      0.00                  0.00
#
#    dst_host_srv_rerror_rate   labels
# 0                      0.00   normal
# 1                      0.00   normal
# 2                      0.00  neptune
# 3                      0.01   normal
# 4                      0.00   normal
#
# [5 rows x 42 columns]

# %%
categ = ['protocol_type','service','flag']
# Encode Categorical Columns
le = LabelEncoder()
data[categ] = data[categ].apply(le.fit_transform)

# %%
labels=[]
for i in data['labels']:
  if i=='normal':
    labels.append(0)
  else:
    labels.append(1)
data['labels']=labels

# %%
X = data.iloc[:,1:41]
Y = data['labels']

# %%
scaler = Normalizer().fit(X)
X = scaler.transform(X)

# %%
X_train, X_test,Y_train,Y_test = train_test_split(X,Y, test_size=0.2)

# %%
# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0],X_train.shape[1],1))
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))

# %%
model = Sequential()
model.add(LSTM(128,input_shape=(40, 1)))  # try using a GRU instead, for fun
model.add(Dropout(0.1))
model.add(Flatten())
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
# define optimizer and objective, compile cnn
model.compile(loss="binary_crossentropy", optimizer="adam",metrics=['accuracy'])

# %%
# train
checkpointer = callbacks.ModelCheckpoint(filepath="results/cnn1results/checkpoint-{epoch:02d}.hdf5", verbose=1, save_best_only=True, monitor='val_acc',mode='max')

# %%
history=model.fit(X_train, Y_train, epochs=100,verbose=1,batch_size=500,validation_data=(X_test, Y_test),callbacks=[checkpointer])
# Out:
# Epoch 1/100
# 236/238 [============================>.] - ETA: 0s - loss: 0.3019 - accuracy: 0.8749WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 21s 39ms/step - loss: 0.3015 - accuracy: 0.8750 - val_loss: 0.2681 - val_accuracy: 0.9079
# Epoch 2/100
# 237/238 [============================>.] - ETA: 0s - loss: 0.2264 - accuracy: 0.9077WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 7s 30ms/step - loss: 0.2263 - accuracy: 0.9077 - val_loss: 0.2085 - val_accuracy: 0.9217
# Epoch 3/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2084 - accuracy: 0.9144WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.2084 - accuracy: 0.9144 - val_loss: 0.1929 - val_accuracy: 0.9124
# Epoch 4/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1957 - accuracy: 0.9233WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.1957 - accuracy: 0.9233 - val_loss: 0.1970 - val_accuracy: 0.9219
# Epoch 5/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1922 - accuracy: 0.9264WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 22ms/step - loss: 0.1922 - accuracy: 0.9264 - val_loss: 0.2047 - val_accuracy: 0.9221
# Epoch 6/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1915 - accuracy: 0.9269WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.1915 - accuracy: 0.9269 - val_loss: 0.1875 - val_accuracy: 0.9265
# Epoch 7/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1900 - accuracy: 0.9276WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.1900 - accuracy: 0.9276 - val_loss: 0.1765 - val_accuracy: 0.9340
# Epoch 8/100
# 235/238 [============================>.] - ETA: 0s - loss: 0.1827 - accuracy: 0.9305WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.1828 - accuracy: 0.9304 - val_loss: 0.1754 - val_accuracy: 0.9337
# Epoch 9/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1805 - accuracy: 0.9307WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 20ms/step - loss: 0.1805 - accuracy: 0.9307 - val_loss: 0.1686 - val_accuracy: 0.9372
# Epoch 10/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1783 - accuracy: 0.9318WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.1783 - accuracy: 0.9318 - val_loss: 0.1658 - val_accuracy: 0.9357
# Epoch 11/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1738 - accuracy: 0.9327WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 20ms/step - loss: 0.1738 - accuracy: 0.9327 - val_loss: 0.1749 - val_accuracy: 0.9368
# Epoch 12/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1758 - accuracy: 0.9317WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 20ms/step - loss: 0.1758 - accuracy: 0.9317 - val_loss: 0.1588 - val_accuracy: 0.9359
# Epoch 13/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1710 - accuracy: 0.9330WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 20ms/step - loss: 0.1710 - accuracy: 0.9330 - val_loss: 0.1760 - val_accuracy: 0.9312
# Epoch 14/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1714 - accuracy: 0.9325WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.1714 - accuracy: 0.9325 - val_loss: 0.1677 - val_accuracy: 0.9343
# Epoch 15/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1676 - accuracy: 0.9334WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 20ms/step - loss: 0.1676 - accuracy: 0.9334 - val_loss: 0.1524 - val_accuracy: 0.9389
# Epoch 16/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1658 - accuracy: 0.9355WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 20ms/step - loss: 0.1658 - accuracy: 0.9355 - val_loss: 0.1571 - val_accuracy: 0.9395
# Epoch 17/100
# 237/238 [============================>.] - ETA: 0s - loss: 0.1621 - accuracy: 0.9355WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 23ms/step - loss: 0.1621 - accuracy: 0.9355 - val_loss: 0.1625 - val_accuracy: 0.9393
# Epoch 18/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1599 - accuracy: 0.9358WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 6s 24ms/step - loss: 0.1599 - accuracy: 0.9358 - val_loss: 0.1465 - val_accuracy: 0.9426
# Epoch 19/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1561 - accuracy: 0.9370WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.1561 - accuracy: 0.9370 - val_loss: 0.1446 - val_accuracy: 0.9406
# Epoch 20/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1611 - accuracy: 0.9379WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 20ms/step - loss: 0.1611 - accuracy: 0.9379 - val_loss: 0.1554 - val_accuracy: 0.9404
# Epoch 21/100
# 237/238 [============================>.] - ETA: 0s - loss: 0.1579 - accuracy: 0.9385WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.1578 - accuracy: 0.9385 - val_loss: 0.1493 - val_accuracy: 0.9379
# Epoch 22/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1496 - accuracy: 0.9404WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 22ms/step - loss: 0.1496 - accuracy: 0.9404 - val_loss: 0.1493 - val_accuracy: 0.9317
# Epoch 23/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1408 - accuracy: 0.9455WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.1408 - accuracy: 0.9455 - val_loss: 0.1381 - val_accuracy: 0.9517
# Epoch 24/100
# 235/238 [============================>.] - ETA: 0s - loss: 0.1358 - accuracy: 0.9467WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.1357 - accuracy: 0.9468 - val_loss: 0.1160 - val_accuracy: 0.9519
# Epoch 25/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1245 - accuracy: 0.9515WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.1245 - accuracy: 0.9515 - val_loss: 0.1206 - val_accuracy: 0.9530
# Epoch 26/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1188 - accuracy: 0.9557WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 20ms/step - loss: 0.1188 - accuracy: 0.9557 - val_loss: 0.1073 - val_accuracy: 0.9606
# Epoch 27/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1134 - accuracy: 0.9568WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 20ms/step - loss: 0.1134 - accuracy: 0.9568 - val_loss: 0.0993 - val_accuracy: 0.9632
# Epoch 28/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1153 - accuracy: 0.9565WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 20ms/step - loss: 0.1153 - accuracy: 0.9565 - val_loss: 0.1495 - val_accuracy: 0.9450
# Epoch 29/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1254 - accuracy: 0.9554WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 20ms/step - loss: 0.1254 - accuracy: 0.9554 - val_loss: 0.1077 - val_accuracy: 0.9580
# Epoch 30/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1089 - accuracy: 0.9598WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.1089 - accuracy: 0.9598 - val_loss: 0.1191 - val_accuracy: 0.9553
# Epoch 31/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1007 - accuracy: 0.9623WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 20ms/step - loss: 0.1007 - accuracy: 0.9623 - val_loss: 0.0937 - val_accuracy: 0.9651
# Epoch 32/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0985 - accuracy: 0.9633WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.0985 - accuracy: 0.9633 - val_loss: 0.0895 - val_accuracy: 0.9692
# Epoch 33/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1000 - accuracy: 0.9630WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.1000 - accuracy: 0.9630 - val_loss: 0.0953 - val_accuracy: 0.9645
# Epoch 34/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1018 - accuracy: 0.9631WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 20ms/step - loss: 0.1018 - accuracy: 0.9631 - val_loss: 0.0868 - val_accuracy: 0.9708
# Epoch 35/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0940 - accuracy: 0.9651WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.0940 - accuracy: 0.9651 - val_loss: 0.1029 - val_accuracy: 0.9602
# Epoch 36/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0911 - accuracy: 0.9662WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.0911 - accuracy: 0.9662 - val_loss: 0.0849 - val_accuracy: 0.9687
# Epoch 37/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0862 - accuracy: 0.9693WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 20ms/step - loss: 0.0862 - accuracy: 0.9693 - val_loss: 0.0803 - val_accuracy: 0.9700
# Epoch 38/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0816 - accuracy: 0.9713WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 20ms/step - loss: 0.0816 - accuracy: 0.9713 - val_loss: 0.0891 - val_accuracy: 0.9676
# Epoch 39/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0898 - accuracy: 0.9683WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 20ms/step - loss: 0.0898 - accuracy: 0.9683 - val_loss: 0.1055 - val_accuracy: 0.9635
# Epoch 40/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0806 - accuracy: 0.9716WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.0806 - accuracy: 0.9716 - val_loss: 0.0740 - val_accuracy: 0.9754
# Epoch 41/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0897 - accuracy: 0.9678WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.0897 - accuracy: 0.9678 - val_loss: 0.0732 - val_accuracy: 0.9727
# Epoch 42/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0785 - accuracy: 0.9724WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 20ms/step - loss: 0.0785 - accuracy: 0.9724 - val_loss: 0.0768 - val_accuracy: 0.9703
# Epoch 43/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0801 - accuracy: 0.9714WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.0801 - accuracy: 0.9714 - val_loss: 0.0664 - val_accuracy: 0.9766
# Epoch 44/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0724 - accuracy: 0.9747WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 20ms/step - loss: 0.0724 - accuracy: 0.9747 - val_loss: 0.0627 - val_accuracy: 0.9778
# Epoch 45/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0719 - accuracy: 0.9750WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 20ms/step - loss: 0.0719 - accuracy: 0.9750 - val_loss: 0.0702 - val_accuracy: 0.9728
# Epoch 46/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0702 - accuracy: 0.9759WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 22ms/step - loss: 0.0702 - accuracy: 0.9759 - val_loss: 0.0727 - val_accuracy: 0.9736
# Epoch 47/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0674 - accuracy: 0.9769WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 22ms/step - loss: 0.0674 - accuracy: 0.9769 - val_loss: 0.0641 - val_accuracy: 0.9788
# Epoch 48/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0688 - accuracy: 0.9765WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.0688 - accuracy: 0.9765 - val_loss: 0.0638 - val_accuracy: 0.9772
# Epoch 49/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0664 - accuracy: 0.9775WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.0664 - accuracy: 0.9775 - val_loss: 0.0601 - val_accuracy: 0.9803
# Epoch 50/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0672 - accuracy: 0.9771WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.0672 - accuracy: 0.9771 - val_loss: 0.0642 - val_accuracy: 0.9782
# Epoch 51/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0675 - accuracy: 0.9771WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.0675 - accuracy: 0.9771 - val_loss: 0.0653 - val_accuracy: 0.9773
# Epoch 52/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0649 - accuracy: 0.9781WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.0649 - accuracy: 0.9781 - val_loss: 0.0591 - val_accuracy: 0.9791
# Epoch 53/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0632 - accuracy: 0.9788WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.0632 - accuracy: 0.9788 - val_loss: 0.0658 - val_accuracy: 0.9780
# Epoch 54/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0655 - accuracy: 0.9780WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 22ms/step - loss: 0.0655 - accuracy: 0.9780 - val_loss: 0.0581 - val_accuracy: 0.9806
# Epoch 55/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0652 - accuracy: 0.9782WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 22ms/step - loss: 0.0652 - accuracy: 0.9782 - val_loss: 0.0596 - val_accuracy: 0.9804
# Epoch 56/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0614 - accuracy: 0.9794WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.0614 - accuracy: 0.9794 - val_loss: 0.0738 - val_accuracy: 0.9733
# Epoch 57/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0614 - accuracy: 0.9792WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 22ms/step - loss: 0.0614 - accuracy: 0.9792 - val_loss: 0.0658 - val_accuracy: 0.9779
# Epoch 58/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0609 - accuracy: 0.9797WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.0609 - accuracy: 0.9797 - val_loss: 0.0573 - val_accuracy: 0.9812
# Epoch 59/100
# 237/238 [============================>.] - ETA: 0s - loss: 0.0598 - accuracy: 0.9801WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 22ms/step - loss: 0.0598 - accuracy: 0.9801 - val_loss: 0.0581 - val_accuracy: 0.9811
# Epoch 60/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0580 - accuracy: 0.9810WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 22ms/step - loss: 0.0580 - accuracy: 0.9810 - val_loss: 0.0610 - val_accuracy: 0.9797
# Epoch 61/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0597 - accuracy: 0.9803WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.0597 - accuracy: 0.9803 - val_loss: 0.0558 - val_accuracy: 0.9817
# Epoch 62/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0647 - accuracy: 0.9785WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.0647 - accuracy: 0.9785 - val_loss: 0.0674 - val_accuracy: 0.9799
# Epoch 63/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0578 - accuracy: 0.9809WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.0578 - accuracy: 0.9809 - val_loss: 0.0584 - val_accuracy: 0.9801
# Epoch 64/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0565 - accuracy: 0.9812WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 22ms/step - loss: 0.0565 - accuracy: 0.9812 - val_loss: 0.0624 - val_accuracy: 0.9784
# Epoch 65/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0565 - accuracy: 0.9813WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.0565 - accuracy: 0.9813 - val_loss: 0.0532 - val_accuracy: 0.9815
# Epoch 66/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0553 - accuracy: 0.9818WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 22ms/step - loss: 0.0553 - accuracy: 0.9818 - val_loss: 0.0694 - val_accuracy: 0.9728
# Epoch 67/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0576 - accuracy: 0.9803WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.0576 - accuracy: 0.9803 - val_loss: 0.0534 - val_accuracy: 0.9826
# Epoch 68/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0656 - accuracy: 0.9782WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.0656 - accuracy: 0.9782 - val_loss: 0.0514 - val_accuracy: 0.9828
# Epoch 69/100
# 236/238 [============================>.] - ETA: 0s - loss: 0.0537 - accuracy: 0.9819WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 22ms/step - loss: 0.0537 - accuracy: 0.9819 - val_loss: 0.0514 - val_accuracy: 0.9832
# Epoch 70/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0533 - accuracy: 0.9822WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.0533 - accuracy: 0.9822 - val_loss: 0.0538 - val_accuracy: 0.9825
# Epoch 71/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0546 - accuracy: 0.9816WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 22ms/step - loss: 0.0546 - accuracy: 0.9816 - val_loss: 0.0513 - val_accuracy: 0.9827
# Epoch 72/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0545 - accuracy: 0.9817WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 22ms/step - loss: 0.0545 - accuracy: 0.9817 - val_loss: 0.0537 - val_accuracy: 0.9822
# Epoch 73/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0533 - accuracy: 0.9823WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 22ms/step - loss: 0.0533 - accuracy: 0.9823 - val_loss: 0.0545 - val_accuracy: 0.9821
# Epoch 74/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0541 - accuracy: 0.9819WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.0541 - accuracy: 0.9819 - val_loss: 0.0557 - val_accuracy: 0.9816
# Epoch 75/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0551 - accuracy: 0.9819WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 22ms/step - loss: 0.0551 - accuracy: 0.9819 - val_loss: 0.0604 - val_accuracy: 0.9793
# Epoch 76/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0522 - accuracy: 0.9826WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 22ms/step - loss: 0.0522 - accuracy: 0.9826 - val_loss: 0.0492 - val_accuracy: 0.9838
# Epoch 77/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0519 - accuracy: 0.9828WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.0519 - accuracy: 0.9828 - val_loss: 0.0498 - val_accuracy: 0.9832
# Epoch 78/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0510 - accuracy: 0.9830WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.0510 - accuracy: 0.9830 - val_loss: 0.0525 - val_accuracy: 0.9828
# Epoch 79/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0507 - accuracy: 0.9830WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 23ms/step - loss: 0.0507 - accuracy: 0.9830 - val_loss: 0.0491 - val_accuracy: 0.9834
# Epoch 80/100
# 237/238 [============================>.] - ETA: 0s - loss: 0.0512 - accuracy: 0.9829WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 22ms/step - loss: 0.0512 - accuracy: 0.9830 - val_loss: 0.0513 - val_accuracy: 0.9833
# Epoch 81/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0506 - accuracy: 0.9830WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 22ms/step - loss: 0.0506 - accuracy: 0.9830 - val_loss: 0.0461 - val_accuracy: 0.9845
# Epoch 82/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0494 - accuracy: 0.9835WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.0494 - accuracy: 0.9835 - val_loss: 0.0456 - val_accuracy: 0.9850
# Epoch 83/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0496 - accuracy: 0.9836WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 22ms/step - loss: 0.0496 - accuracy: 0.9836 - val_loss: 0.0513 - val_accuracy: 0.9822
# Epoch 84/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0499 - accuracy: 0.9832WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 22ms/step - loss: 0.0499 - accuracy: 0.9832 - val_loss: 0.0495 - val_accuracy: 0.9835
# Epoch 85/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0482 - accuracy: 0.9840WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.0482 - accuracy: 0.9840 - val_loss: 0.0461 - val_accuracy: 0.9848
# Epoch 86/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0472 - accuracy: 0.9841WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 22ms/step - loss: 0.0472 - accuracy: 0.9841 - val_loss: 0.0455 - val_accuracy: 0.9849
# Epoch 87/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0466 - accuracy: 0.9844WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.0466 - accuracy: 0.9844 - val_loss: 0.0441 - val_accuracy: 0.9853
# Epoch 88/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0466 - accuracy: 0.9843WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 22ms/step - loss: 0.0466 - accuracy: 0.9843 - val_loss: 0.0533 - val_accuracy: 0.9832
# Epoch 89/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0471 - accuracy: 0.9841WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.0471 - accuracy: 0.9841 - val_loss: 0.0529 - val_accuracy: 0.9826
# Epoch 90/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0515 - accuracy: 0.9828WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.0515 - accuracy: 0.9828 - val_loss: 0.0481 - val_accuracy: 0.9844
# Epoch 91/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0455 - accuracy: 0.9845WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.0455 - accuracy: 0.9845 - val_loss: 0.0464 - val_accuracy: 0.9849
# Epoch 92/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0464 - accuracy: 0.9845WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.0464 - accuracy: 0.9845 - val_loss: 0.0436 - val_accuracy: 0.9857
# Epoch 93/100
# 237/238 [============================>.] - ETA: 0s - loss: 0.0465 - accuracy: 0.9845WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 22ms/step - loss: 0.0465 - accuracy: 0.9846 - val_loss: 0.0516 - val_accuracy: 0.9827
# Epoch 94/100
# 237/238 [============================>.] - ETA: 0s - loss: 0.0445 - accuracy: 0.9850WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 22ms/step - loss: 0.0446 - accuracy: 0.9850 - val_loss: 0.0493 - val_accuracy: 0.9831
# Epoch 95/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0462 - accuracy: 0.9844WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 22ms/step - loss: 0.0462 - accuracy: 0.9844 - val_loss: 0.0472 - val_accuracy: 0.9849
# Epoch 96/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0437 - accuracy: 0.9849WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 22ms/step - loss: 0.0437 - accuracy: 0.9849 - val_loss: 0.0441 - val_accuracy: 0.9854
# Epoch 97/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0476 - accuracy: 0.9839WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.0476 - accuracy: 0.9839 - val_loss: 0.0455 - val_accuracy: 0.9844
# Epoch 98/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0446 - accuracy: 0.9849WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 22ms/step - loss: 0.0446 - accuracy: 0.9849 - val_loss: 0.0540 - val_accuracy: 0.9812
# Epoch 99/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0429 - accuracy: 0.9856WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.0429 - accuracy: 0.9856 - val_loss: 0.0467 - val_accuracy: 0.9838
# Epoch 100/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0448 - accuracy: 0.9850WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 238/238 [==============================] - 5s 21ms/step - loss: 0.0448 - accuracy: 0.9850 - val_loss: 0.0491 - val_accuracy: 0.9846

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
model.save("results/cnn1results/cnn_model.hdf5")
